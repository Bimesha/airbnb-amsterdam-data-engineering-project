# %% [markdown]
# 04.Price Prediction
# This notebook is a simple narrative summary created from the project output reports. It does not replace the Python scripts; it helps explain the results.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import Image, display

reports = Path("../reports")
figures = Path("../figures")
pd.set_option("display.max_columns", None)

# %% [markdown]
# Model Comparison

# %%
results = pd.read_csv(reports / "price_prediction_results.csv")
results
# Out:
#                model  cross_validation_mae  test_mae  test_rmse  test_r2
# 0  Linear Regression                 68.42     67.77      97.20   0.5179
# 1      Random Forest                 67.11     66.79      96.61   0.5237

# %% [markdown]
# Feature Importance

# %%
feature_importance = pd.read_csv(reports / "price_prediction_feature_importance.csv")
feature_importance.head(15)
# Out:
#                                            feature  importance
# 0                                     accommodates    0.332263
# 1                                         bedrooms    0.091261
# 2                                 availability_365    0.088996
# 3                           room_type_Private room    0.072292
# 4                                     review_count    0.068878
# 5                             review_scores_rating    0.063431
# 6                                   occupancy_rate    0.042819
# 7              neighbourhood_cleansed_Centrum-West    0.038977
# 8                                             beds    0.029333
# 9              neighbourhood_cleansed_Centrum-Oost    0.027057
# 10   neighbourhood_cleansed_De Baarsjes - Oud-West    0.019237
# 11  neighbourhood_cleansed_De Pijp - Rivierenbuurt    0.015929
# 12               neighbourhood_cleansed_Noord-West    0.011367
# 13                     property_type_Room in hotel    0.009376
# ...

# %%
display(Image(filename=str(figures / "price_prediction_feature_importance.png")))

# %% [markdown]
# Interpretation
#
# This was a simple optional experiment, not a production model.
