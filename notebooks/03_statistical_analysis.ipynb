# %% [markdown]
# 03.Statistical Analysis
#
# This notebook is a simple narrative summary created from the project output reports. It does not replace the Python scripts; it helps explain the results.

# %%
from pathlib import Path
import pandas as pd

reports = Path("../reports/generated_csv")
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", 120)

# %% [markdown]
# Statistical Test Results

# %%
stats = pd.read_csv(reports / "statistical_test_results.csv")
stats
# Out:
#   hypothesis  \
# 0         H1
# 1         H2
# 2         H3
# 3         H4
# 4         H5
#
#                                                                 question  \
# 0               Do entire homes and private rooms have different prices?
# 1  Do superhost and non-superhost listings have different review scores?
# 2           Do listings with more than 10 reviews have different prices?
# 3                          Do prices differ across major neighbourhoods?
# 4                              Are weekend and weekday prices different?
#
#              test_used               group_1              group_2  \
# 0  Mann-Whitney U test       Entire home/apt         Private room
# 1  Mann-Whitney U test             Superhost        Non-superhost
# 2  Mann-Whitney U test  More than 10 reviews  10 or fewer reviews
# 3        One-way ANOVA  Top 5 neighbourhoods       Not applicable
# 4        Not performed               Weekend              Weekday
#
# ...

# %% [markdown]
# Key Result Columns

# %%
stats[["hypothesis", "test_used", "p_value", "interpretation"]]
# Out:
#   hypothesis            test_used   p_value  \
# 0         H1  Mann-Whitney U test  0.000000
# 1         H2  Mann-Whitney U test  0.000000
# 2         H3  Mann-Whitney U test  0.000000
# 3         H4        One-way ANOVA  0.004567
# 4         H5        Not performed       NaN
#
#                                                                                                 interpretation
# 0                                                                  Statistically significant difference found.
# 1                                                                  Statistically significant difference found.
# 2                                                                  Statistically significant difference found.
# 3                                                                  Statistically significant difference found.
# 4  This test was not performed because calendar price and adjusted_price are missing in the Amsterdam dataset.

# %% [markdown]
# Business Interpretation
# Statistical significance does not always mean a large practical difference. Review the practical difference column before making business decisions.
